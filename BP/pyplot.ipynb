# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
   
def logplotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title,lfit=0):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title) 
    plt.grid()
    
    for i in range(n):
        data=pd.read_csv(data_file_list[i],sep='\s+',header=None)
        x=data[x_index]
        y=data[y_index]
        x=np.log(x)
        y=np.log(y)
        plt.plot(x, y,label=data_label_list[i])
    
    if lfit!=0:
        fit=lfit*x
        plt.plot(x, fit,label="linear fit: slope=%f"%lfit)
        
    plt.legend()
    plt.show()

def plotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title,lfit=0):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title) 
    plt.grid()
    
    for i in range(n):
        data=pd.read_csv(data_file_list[i],sep='\s+',header=None)
        x=data[x_index]
        y=data[y_index]
        plt.plot(x, y,label=data_label_list[i])
        
    if lfit!=0:
        fit=lfit*x
        plt.plot(x, fit,label="linear fit: slope=%f"%lfit)
        
    plt.legend()
    plt.show()

# %%
#p=0.01, #index: n=0, fail_rate=1, wt/avg_p=2, avg_iter=3 number_of_suc_decoding=4
n=3
data_file1='p0.005-0.015_data.txt'
data_file2='p0.01-0.01_data.txt'
data_file3='p0.008-0.012_data.txt'
data_file_list=[data_file1,data_file2,data_file3]

xlabel='n'
ylabel='fail rate'

data1_label="avg=0.01, range=0.005"
data2_label="0"
data3_label="avg=0.01,range=0.002"
data_label_list=[data1_label,data2_label,data3_label]

x_index=0
y_index=1
title="diff p vs same p"

plotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title)

#use #/frac of fails

# %%
#n=128
n=2
data_file1='n128_data.txt'
data_file2='n128sp_data.txt'
data_file_list=[data_file1,data_file2]

xlabel='p'
ylabel='fail rate'
data1_label="diff p:(0.004i,0.006i)"
data2_label="same p:(0.005i,0.005i)"
data_label_list=[data1_label,data2_label]

x_index=2
y_index=1
title="n=128:diff p vs same p"

plotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title)

# %%
#p=0.01, classical Mackay's code
n=3
data_file1='c_p0.06-0.06_data.txt'
data_file2='c_p0.05-0.07_data.txt'
data_file3='c_p0.04-0.08_data.txt'
data_file_list=[data_file1,data_file2,data_file3]
xlabel='n'
ylabel='fail rate'
data1_label="avg=0.06, range=0"
data2_label="avg=0.06,range=0.01"
data3_label="avg=0.06,range=0.02"
data_label_list=[data1_label,data2_label,data3_label]
x_index=0
y_index=1

title="diff p vs same p"

plotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title)

fit=-0.5
logplotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title,fit)

# %%
#n=18/32/50 surface code
n=3


data_file1='n18_data.txt'
data_file2='n32_data.txt'
data_file3='n50_data.txt'
data_file_list=[data_file1,data_file2,data_file3]
xlabel='p'
ylabel='fail rate'
data1_label="n=18"
data2_label="n=32"
data3_label="n=50"
data_label_list=[data1_label,data2_label,data3_label]
x_index=2
y_index=1

title="surface code"

plotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title)

title="surface code log"
fit=2
logplotn(n,data_file_list,x_index,y_index,xlabel,ylabel,data_label_list,title,fit)
# Out:
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#n=96 classical code

cn96data= pd.read_csv('M1_data.txt',sep='\s+',header=None)

x=cn96data[2]
y=cn96data[1]



plt.xlabel('p')
plt.ylabel('failure rate')

plt.plot(x, y,"r",label="n=96")

plt.legend()
plt.show()

logx=np.log(x)
logy=np.log(y)

plt.xlabel('p')
plt.ylabel('failure rate')
plt.grid()
plt.plot(logx, logy,"r",label="n=96")

plt.legend()
plt.show()


y=cn96data[3]



plt.xlabel('p')
plt.ylabel('avg iter')

plt.plot(x, y,"r",label="n=96")

plt.legend()
plt.show()

x=cn96data[2]
y=cn96data[5]

logx=np.log(x)
logy=np.log(y)

fity=3*logx

plt.grid()
plt.xlabel('n')
plt.ylabel('bit error rate after decoding')

plt.plot(logx, logy,"r",label="n=96") 
plt.plot(logx, fity,"r",label="fit") 

plt.legend()
plt.show()
# Out:
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#n=18 surface code failure rate

n18data= pd.read_csv('n18_data2.txt',sep='\s+',header=None)
n32data=

x=n18data[2]
y=n18data[1]


plt.xlabel('p')
plt.ylabel('failure rate')

plt.plot(x, y,"r",label="n=18")#0.005-0.015  

plt.legend()
plt.show()


logy=np.log(y)

logx=np.log(x)
plt.xlabel('p')
plt.ylabel('failure rate')

plt.plot(logx, logy,"r",label="n=18")#0.005-0.015  

plt.legend()
plt.show()


x=n18data[2]
y=n18data[3]


plt.xlabel('p')
plt.ylabel('avergare iter')

plt.plot(x, y,"r",label="n=18")#0.005-0.015  

plt.legend()
plt.show()
# Out:
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#index: n=0, fail_rate=1, wt/avg_p=2, avg_iter=3 number_of_suc_decoding=4
xlabel="wt"
ylabel="fail_rate"
data1_label="diff p:(0.5,1.5)*wt/n"
data2_label="same p:wt/n"

plotn(2,["wt_n72d.txt","wt_n72s.txt"],2,1,xlabel,ylabel,[data1_label,data2_label],"n=72 toric d=6")
plotn(2,["wt_n50d.txt","wt_n50s.txt"],2,1,xlabel,ylabel,[data1_label,data2_label],"n=50 toric d=5")
plotn(2,["wt_n18d.txt","wt_n18s.txt"],2,1,xlabel,ylabel,[data1_label,data2_label],"n=18 toric d=3")
plotn(2,["wt_n200d.txt","wt_n200s.txt"],2,1,xlabel,ylabel,[data1_label,data2_label],"n=200 toric d=10")
#just try x first, see fail config position,

# %%
#bicycle test
#index: n=0, fail_rate=1, wt/avg_p=2, avg_iter=3 number_of_suc_decoding=4
xlabel="n"
ylabel="fail_rate"
data1_label="wt4"
data2_label="wt6"
data1="GBw4p0.005-0.015_data.txt"
data2="GBw6p0.005-0.015_data.txt"
plotn(2,[data1,data2],0,1,xlabel,ylabel,[data1_label,data2_label],"bicycle,p=(0.005,0.015)")
#w/out range, p 10^-3~10%, 20 points, vector jobs in hpcc

# %%
#decode x errors only:
#index: n=0, fail_rate=1, wt/avg_p=2, avg_iter=3 number_of_suc_decoding=4
xlabel="wt"
ylabel="fail_rate"
data1_label="range=0"
data2_label="range=0.1"
data3_label="range=0.2"
data4_label="range=0.3"
data5_label="range=0.6"
data6_label="range=0.9"
data7_label="range=1.0"
data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label,data7_label]

n18data=["wt_n18_0.0.txt","wt_n18_0.1.txt","wt_n18_0.2.txt","wt_n18_0.3.txt","wt_n18_0.6.txt","wt_n18_0.9.txt","wt_n18_1.0.txt"]
n50data=["wt_n50_0.0.txt","wt_n50_0.1.txt","wt_n50_0.2.txt","wt_n50_0.3.txt","wt_n50_0.6.txt","wt_n50_0.9.txt","wt_n50_1.0.txt"]
n72data=["wt_n72_0.0.txt","wt_n72_0.1.txt","wt_n72_0.2.txt","wt_n72_0.3.txt","wt_n72_0.6.txt","wt_n72_0.9.txt","wt_n72_1.0.txt"]
n200data=["wt_n200_0.0.txt","wt_n200_0.1.txt","wt_n200_0.2.txt","wt_n200_0.3.txt","wt_n200_0.6.txt","wt_n200_0.9.txt","wt_n200_1.0.txt"]

print("p=wt/n*(1-range,1+range), only decode z-errors(use Hx), max_iterations=20")
plotn(7,n72data,2,1,xlabel,ylabel,data_label,"n=72 toric d=6")
plotn(7,n50data,2,1,xlabel,ylabel,data_label,"n=50 toric d=5")
plotn(7,n18data,2,1,xlabel,ylabel,data_label,"n=18 toric d=3")
plotn(7,n200data,2,1,xlabel,ylabel,data_label,"n=200 toric d=10")
# Out:
# p=wt/n*(1-range,1+range), only decode z-errors(use Hx), max_iterations=20

# %%
#when reaches maximum iterations, try another p_dist: [0.5,1.5]*wt/n, then decode another time
n18data=["2wt_n18_0.0.txt","2wt_n18_0.1.txt","2wt_n18_0.2.txt","2wt_n18_0.3.txt","2wt_n18_0.6.txt","2wt_n18_0.9.txt","2wt_n18_1.0.txt"]
n50data=["2wt_n50_0.0.txt","2wt_n50_0.1.txt","2wt_n50_0.2.txt","2wt_n50_0.3.txt","2wt_n50_0.6.txt","2wt_n50_0.9.txt","2wt_n50_1.0.txt"]
n72data=["2wt_n72_0.0.txt","2wt_n72_0.1.txt","2wt_n72_0.2.txt","2wt_n72_0.3.txt","2wt_n72_0.6.txt","2wt_n72_0.9.txt","2wt_n72_1.0.txt"]
n200data=["2wt_n200_0.0.txt","2wt_n200_0.1.txt","2wt_n200_0.2.txt","2wt_n200_0.3.txt","2wt_n200_0.6.txt","2wt_n200_0.9.txt","2wt_n200_1.0.txt"]

print("p=wt/n*(1-range,1+range), only decode z-errors(use Hx), max_iterations=20")
plotn(7,n72data,2,1,xlabel,ylabel,data_label,"n=72 toric d=6")
plotn(7,n50data,2,1,xlabel,ylabel,data_label,"n=50 toric d=5")
plotn(7,n18data,2,1,xlabel,ylabel,data_label,"n=18 toric d=3")
plotn(7,n200data,2,1,xlabel,ylabel,data_label,"n=200 toric d=10")
# Out:
# p=wt/n*(1-range,1+range), only decode z-errors(use Hx), max_iterations=20

# %%
#p=(0.0002,0.002), 50,000 codewords, 

xlabel="p"
ylabel="fail_rate"
data1_label="range=0"
data2_label="range=0.1"
data3_label="range=0.2"
data4_label="range=0.3"
data5_label="range=0.6"
data6_label="range=0.9"
data7_label="range=1.0"
data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label,data7_label]

n18data=["smallp_n18_0.0.txt","smallp_n18_0.1.txt","smallp_n18_0.2.txt","smallp_n18_0.3.txt","smallp_n18_0.6.txt","smallp_n18_0.9.txt","smallp_n18_1.0.txt"]
n50data=["smallp_n50_0.0.txt","smallp_n50_0.1.txt","smallp_n50_0.2.txt","smallp_n50_0.3.txt","smallp_n50_0.6.txt","smallp_n50_0.9.txt","smallp_n50_1.0.txt"]
n72data=["smallp_n72_0.0.txt","smallp_n72_0.1.txt","smallp_n72_0.2.txt","smallp_n72_0.3.txt","smallp_n72_0.6.txt","smallp_n72_0.9.txt","smallp_n72_1.0.txt"]
n200data=["smallp_n200_0.0.txt","smallp_n200_0.1.txt","smallp_n200_0.2.txt","smallp_n200_0.3.txt","smallp_n200_0.6.txt","smallp_n200_0.9.txt","smallp_n200_1.0.txt"]

print("p=(0.0002,0.002), max_iterations=20, 50,000 codewords")
logplotn(7,n72data,2,1,xlabel,ylabel,data_label,"n=72 toric d=6")
logplotn(7,n50data,2,1,xlabel,ylabel,data_label,"n=50 toric d=5")
logplotn(7,n18data,2,1,xlabel,ylabel,data_label,"n=18 toric d=3")
logplotn(7,n200data,2,1,xlabel,ylabel,data_label,"n=200 toric d=10")
# Out:
# p=(0.0002,0.002), max_iterations=20, 50,000 codewords
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
# ...

# %%
#p=(0.001,0.01), 10,000 codewords, 
xlabel="p"
ylabel="fail_rate"
data1_label="range=0"
data2_label="range=0.1"
data3_label="range=0.2"
data4_label="range=0.3"
data5_label="range=0.6"
data6_label="range=0.9"
data7_label="range=1.0"
data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label,data7_label]

n18data=["2smallp_n18_0.0.txt","2smallp_n18_0.1.txt","2smallp_n18_0.2.txt","2smallp_n18_0.3.txt","2smallp_n18_0.6.txt","2smallp_n18_0.9.txt","2smallp_n18_1.0.txt"]
n50data=["2smallp_n50_0.0.txt","2smallp_n50_0.1.txt","2smallp_n50_0.2.txt","2smallp_n50_0.3.txt","2smallp_n50_0.6.txt","2smallp_n50_0.9.txt","2smallp_n50_1.0.txt"]
n72data=["2smallp_n72_0.0.txt","2smallp_n72_0.1.txt","2smallp_n72_0.2.txt","2smallp_n72_0.3.txt","2smallp_n72_0.6.txt","2smallp_n72_0.9.txt","2smallp_n72_1.0.txt"]
n200data=["2smallp_n200_0.0.txt","2smallp_n200_0.1.txt","2smallp_n200_0.2.txt","2smallp_n200_0.3.txt","2smallp_n200_0.6.txt","2smallp_n200_0.9.txt","2smallp_n200_1.0.txt"]

print("p=(0.001,0.01)*(1-range,1+range), max_iterations=20, 10,000 codewords")
plotn(7,n72data,2,1,xlabel,ylabel,data_label,"n=72 toric d=6")
plotn(7,n50data,2,1,xlabel,ylabel,data_label,"n=50 toric d=5")
plotn(7,n18data,2,1,xlabel,ylabel,data_label,"n=18 toric d=3")
plotn(7,n200data,2,1,xlabel,ylabel,data_label,"n=200 toric d=10")
# Out:
# p=(0.001,0.01)*(1-range,1+range), max_iterations=20, 10,000 codewords

# %%
xlabel="p"
ylabel="fail_rate"
data1_label="range=0"
data2_label="range=0.1"
data3_label="range=0.2"
data4_label="range=0.3"
data5_label="range=0.6"
data6_label="range=0.9"

data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label]


n200datas=["200_0.0_s.data","200_0.1_s.data","200_0.2_s.data","200_0.3_s.data","200_0.6_s.data","200_0.9_s.data"]
n200datap=["200_0.0_p.data","200_0.1_p.data","200_0.2_p.data","200_0.3_p.data","200_0.6_p.data","200_0.9_p.data"]
print("p=(0.001,0.01)*(1-range,1+range), max_iterations=100, 10,000 codewords")

plotn(6,n200datas,3,2,xlabel,ylabel,data_label,"n=200 toric, serial")
plotn(6,n200datap,3,2,xlabel,ylabel,data_label,"n=200 toric, parallel")
# Out:
# p=(0.001,0.01)*(1-range,1+range), max_iterations=100, 10,000 codewords

# %%
#plot1.py
n200datas_2=["200_0.0_s2.data","200_0.1_s2.data","200_0.2_s2.data","200_0.3_s2.data","200_0.6_s2.data","200_0.9_s2.data"]
n200datap_2=["200_0.0_p2.data","200_0.1_p2.data","200_0.2_p2.data","200_0.3_p2.data","200_0.6_p2.data","200_0.9_p2.data"]
print("p=(0.001,0.01)*(1-range,1+range), max_iterations=100, 10,000 codewords, try again if reach max iter")

plotn(6,n200datas_2,3,2,xlabel,ylabel,data_label,"n=200 toric, serial")
plotn(6,n200datap_2,3,2,xlabel,ylabel,data_label,"n=200 toric, parallel")
# Out:
# p=(0.001,0.01)*(1-range,1+range), max_iterations=100, 10,000 codewords, try again if reach max iter

# %%
#plot2.py
n578datas_2=["578_0.0_s2.data","578_0.1_s2.data","578_0.2_s2.data","578_0.3_s2.data","578_0.6_s2.data","578_0.9_s2.data"]

print("p=(0.01,0.1)*(1-range,1+range), max_iterations=100, 1,000 codewords, try again if fails")

plotn(6,n578datas_2,3,2,xlabel,ylabel,data_label,"n=578 toric, serial")
# Out:
# p=(0.01,0.1)*(1-range,1+range), max_iterations=100, 1,000 codewords, try again if fails

# %%
#plot2.py
n578datas_2=["578_0.9_s2_alpha.data","578_0.9_s2.data"]

print("p=(0.01,0.1)*(1-range,1+range), max_iterations=100, 1,000 codewords, try again if fails")
data_label=["alpha=0.65","alpha=1"]
plotn(2,n578datas_2,3,2,xlabel,ylabel,data_label,"n=578 toric, serial")

n578datas_2=["578_0.9_s2_0.2.data","578_0.9_s2_0.5.data"]
data_label=["decode_p=(0,0.4)","decode_p=(0,1)"]

print("try random decode p, max_iterations=100, 1,000 codewords, try again if fails")
data_label=["random decode p"]
plotn(2,n578datas_2,3,2,xlabel,ylabel,data_label,"n=578 toric, serial")
# Out:
# p=(0.01,0.1)*(1-range,1+range), max_iterations=100, 1,000 codewords, try again if fails
# try random decode p, max_iterations=100, 1,000 codewords, try again if fails
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_20217/4023300289.py in <module>
#      11 print("try random decode p, max_iterations=100, 1,000 codewords, try again if fails")
#      12 data_label=["random decode p"]
# ---> 13 plotn(2,n578datas_2,3,2,xlabel,ylabel,data_label,"n=578 toric, serial")
#
# /tmp/ipykernel_20217/1565269455.py in plotn(n, data_file_list, x_index, y_index, xlabel, ylabel, data_label_list, title, lfit)
#      34         x=data[x_index]
#      35         y=data[y_index]
# ---> 36         plt.plot(x, y,label=data_label_list[i])
#      37
#      38     if lfit!=0:
#
# IndexError: list index out of range

# %%
#plot1.py, fixed real_p,
xlabel="p"
ylabel="fail_rate"
data1_label="range=0"
data2_label="range=0.1"
data3_label="range=0.2"
data4_label="range=0.3"
data5_label="range=0.6"
data6_label="range=0.9"

data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label]


n200datas=["200_0.0_s2_fixrp.data","200_0.1_s2_fixrp.data","200_0.2_s2_fixrp.data","200_0.3_s2_fixrp.data","200_0.6_s2_fixrp.data","200_0.9_s2_fixrp.data"]
n200datap=["200_0.0_p2_fixrp.data","200_0.1_p2_fixrp.data","200_0.2_p2_fixrp.data","200_0.3_p2_fixrp.data","200_0.6_p2_fixrp.data","200_0.9_p2_fixrp.data"]
print("realp=(0.001,0.01),decode_p=(0.001,0.01)*(1-range,1+range), max_iterations=100, 10,000 codewords, try again if reaches max iteration")

logplotn(6,n200datas,3,2,xlabel,ylabel,data_label,"n=200 toric, serial")
logplotn(6,n200datap,3,2,xlabel,ylabel,data_label,"n=200 toric, parallel")
# Out:
# realp=(0.001,0.01),decode_p=(0.001,0.01)*(1-range,1+range), max_iterations=100, 10,000 codewords, try again if reaches max iteration
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/xingrui/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#wt_toric.py, range_0.0s.data, avgP=0.01
xlabel="n"
ylabel="fail_rate"
data1_label="range=0"
data2_label="range=0.1"
data3_label="range=0.2"
data4_label="range=0.3"
data5_label="range=0.6"
data6_label="range=0.9"

data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label]


datas=["range_0.0s.data","range_0.1s.data","range_0.2s.data","range_0.3s.data","range_0.6s.data","range_0.9s.data"]
datap=["range_0.0p.data","range_0.1p.data","range_0.2p.data","range_0.3p.data","range_0.6p.data","range_0.9p.data"]
print("realp=decode_p=0.01*(1-range,1+range), max_iterations=100, 10,000 codewords, try again if reaches max iteration")

plotn(6,datas,0,2,xlabel,ylabel,data_label,"p=0.01, serial")
plotn(6,datap,0,2,xlabel,ylabel,data_label,"p=0.01, parallel")
# Out:
# realp=decode_p=0.01*(1-range,1+range), max_iterations=100, 10,000 codewords, try again if reaches max iteration

# %%
import numpy as np
import pandas as pd

data_file="test.data"
target_file="test1.data"
data=pd.read_csv(data_file, sep='\s+',header=None)
data=data.to_numpy()

rows=data.shape[0]
newdata=np.zeros((1,14))

same=[0,1,3,4,12,13]
add=[6,7,8,9]
divide=[2,10,11] #2=(7-6)/7, 10=8/7, 11=9/7
avg=5

for i in same:
    newdata[0,i]=data[0,i]

for i in range(rows):
    newdata[0,5]=newdata[0,5]+data[i,5]*data[i,7]
    for j in add:
        newdata[0,j]=newdata[0,j]+data[i,j]
        

newdata[0,5]=newdata[0,5]/float(newdata[0,7])
print(newdata[0,5])
newdata[0,2]=(newdata[0,7]-newdata[0,6])/float(newdata[0,7])
print(newdata[0,2])
newdata[0,10]=newdata[0,8]/float(newdata[0,7])
print(newdata[0,10])
print(newdata[0,8])
newdata[0,11]=newdata[0,9]/float(newdata[0,7])
print(newdata[0,11])


np.savetxt(target_file, newdata, fmt='%.6f',delimiter=' ', newline='\n', encoding=None)
# Out:
# 2.862741666666666
# 0.008583333333333333
# 0.0
# 0.0
# 0.008583333333333333

# %%
import numpy as np
import pandas as pd
def combine(data_file_list,target_file):
    
    n_data=data_file_list.len()
    newdata=np.zeros((n_data,14))
    
    same=[0,1,3,4,12,13]
    add=[6,7,8,9]
    divide=[2,10,11] #2=(7-6)/7, 10=8/7, 11=9/7
    avg=5
    row_index=0
    
    for data_file in data_file_list:

        data=pd.read_csv(data_file, sep='\s+',header=None)
        data=data.to_numpy()
        rows=data.shape[0]    

        for i in same:
            newdata[row_index,i]=data[0,i]

        for i in range(rows):
            newdata[row_index,5]=newdata[row_index,5]+data[i,5]*data[i,7]
        for j in add:
            newdata[row_index,j]=newdata[row_index,j]+data[i,j]
        
        newdata[row_index,5]=newdata[row_index,5]/float(newdata[row_index,7])
        newdata[row_index,2]=(newdata[row_index,7]-newdata[row_index,6])/float(newdata[row_index,7])
        newdata[row_index,10]=newdata[row_index,8]/float(newdata[row_index,7])
        newdata[row_index,11]=newdata[row_index,9]/float(newdata[row_index,7])
    print(newdata)
    np.savetxt(target_file, newdata, fmt='%.6f',delimiter=' ', newline='\n', encoding=None)

pavg_list = [float(x)*0.001 for x in range(1,11)]
range_list=[0,0.1,0.2,0.3,0.6,0.9]
for r in range_list:
    data_file_list_s=[]
    data_file_list_p=[]
    for p in pavg_list:
        data_file_list_s.append("n200_range%.1f_p%.3f_serial2.data "%(r,p))
        data_file_list_p.append("n200_range%.1f_p%.3f_parallel2.data "%(r,p))
        
    combine( data_file_list_s,"n200_range%.1f_serial2.data "%r)
    combine( data_file_list_p,"n200_range%.1f__parallel2.data "%r)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_34333/4209711736.py in <module>
#      34 for p in pavg_list:
#      35     for r in range_list:
# ---> 36         combine( "n200_range%.1f_p%.3f_serial2.data "%(r,p),"n200_range%.1f_p%.3f_serial2_sum.data "%(r,p))
#      37         combine( "n200_range%.1f_p%.3f_parellel2.data "%(r,p),"n200_range%.1f_p%.3f_parallel2_sum.data "%(r,p))
#
# /tmp/ipykernel_34333/4209711736.py in combine(data_file, target_file)
#       3 def combine(data_file,target_file):
#       4
# ----> 5     data=pd.read_csv(data_file, sep='\s+',header=None)
#       6     data=data.to_numpy()
#       7
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
# ...

# %%
import numpy as np
import pandas as pd
def combine(data_file_list,target_file):
    
    n_data=len(data_file_list)
    newdata=np.zeros((n_data,14))
    
    same=[0,1,3,4,12,13]
    add=[6,7,8,9]
    divide=[2,10,11] #2=(7-6)/7, 10=8/7, 11=9/7
    avg=5
    row_index=0
    
    for data_file in data_file_list:

        data=pd.read_csv(data_file, sep='\s+',header=None)
        data=data.to_numpy()
        rows=data.shape[0]    

        for i in same:
            newdata[row_index,i]=data[0,i]

        for i in range(rows):
            newdata[row_index,5]=newdata[row_index,5]+data[i,5]*data[i,7]
        for j in add:
            newdata[row_index,j]=newdata[row_index,j]+data[i,j]
        
        newdata[row_index,5]=newdata[row_index,5]/float(newdata[row_index,7])
        newdata[row_index,2]=(newdata[row_index,7]-newdata[row_index,6])/float(newdata[row_index,7])
        newdata[row_index,10]=newdata[row_index,8]/float(newdata[row_index,7])
        newdata[row_index,11]=newdata[row_index,9]/float(newdata[row_index,7])
        row_index=row_index+1
    print(newdata)
    np.savetxt(target_file, newdata, fmt='%.6f',delimiter=' ', newline='\n', encoding=None)

pavg_list = [float(x)*0.001 for x in range(1,11)]
range_list=[0,0.1,0.2,0.3,0.6,0.9]
for r in range_list:
    data_file_list_s=[]
    data_file_list_p=[]
    for p in pavg_list:
        data_file_list_s.append("n200_range%.1f_p%.3f_serial2.data"%(r,p))
        data_file_list_p.append("n200_range%.1f_p%.3f_parallel2.data"%(r,p))
        
    combine(data_file_list_s  ,"n200_range%.1f_serial2.data"%r)
    combine( data_file_list_p,"n200_range%.1f__parallel2.data"%r)
# Out:
# [[ 2.00000e+02 -1.00000e+00  0.00000e+00  1.00000e-03  0.00000e+00
#    1.50000e-01  2.00000e+01  2.00000e+01  0.00000e+00  0.00000e+00
#    0.00000e+00  0.00000e+00  1.00000e-03  0.00000e+00]
#  [ 2.00000e+02 -1.00000e+00  0.00000e+00  2.00000e-03  0.00000e+00
#    3.00000e-01  2.00000e+01  2.00000e+01  0.00000e+00  0.00000e+00
#    0.00000e+00  0.00000e+00  2.00000e-03  0.00000e+00]
#  [ 2.00000e+02 -1.00000e+00  0.00000e+00  3.00000e-03  0.00000e+00
#    4.00000e-01  2.00000e+01  2.00000e+01  0.00000e+00  0.00000e+00
#    0.00000e+00  0.00000e+00  3.00000e-03  0.00000e+00]
#  [ 2.00000e+02 -1.00000e+00  0.00000e+00  4.00000e-03  0.00000e+00
#    5.50000e-01  2.00000e+01  2.00000e+01  0.00000e+00  0.00000e+00
#    0.00000e+00  0.00000e+00  4.00000e-03  0.00000e+00]
#  [ 2.00000e+02 -1.00000e+00  0.00000e+00  5.00000e-03  0.00000e+00
#    6.00000e-01  2.00000e+01  2.00000e+01  0.00000e+00  0.00000e+00
#    0.00000e+00  0.00000e+00  5.00000e-03  0.00000e+00]
# ...

# %%
xlabel="n"
ylabel="fail_rate"
data1_label="alpha=0.5"
data2_label="alpha=0.6"
data3_label="alpha=0.7"
data4_label="alpha=0.8"
data5_label="alpha=0.9"
data6_label="alpha=1.0"

data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label]


datas=["alpha0.5_serial.data","alpha0.6_serial.data","alpha0.7_serial.data","alpha0.8_serial.data","alpha0.9_serial.data","alpha1.0_serial.data"]
datap=["alpha0.5_parallel.data","alpha0.6_parallel.data","alpha0.7_parallel.data","alpha0.8_parallel.data","alpha0.9_parallel.data","alpha1.0_parallel.data"]
print("realp=decode_p=0.05*(0.1,1.9), max_iterations=100, 10,000 codewords, try again if reaches max iteration")

plotn(6,datas,0,2,xlabel,ylabel,data_label,"p=0.01, serial")
plotn(6,datap,0,2,xlabel,ylabel,data_label,"p=0.01, parallel")
# Out:
# realp=decode_p=0.01*(0.1,1.9), max_iterations=100, 10,000 codewords, try again if reaches max iteration

# %%
xlabel="p"
ylabel="fail_rate"
data1_label="alpha=0.5"
data2_label="alpha=0.6"
data3_label="alpha=0.7"
data4_label="alpha=0.8"
data5_label="alpha=0.9"
data6_label="alpha=1.0"

data_label=[data1_label,data2_label,data3_label,data4_label,data5_label,data6_label]


datas=["alpha0.5_d5_serial.data","alpha0.6_d5_serial.data","alpha0.7_d5_serial.data","alpha0.8_d5_serial.data","alpha0.9_d5_serial.data","alpha1.0_d5_serial.data"]
datap=["alpha0.5_d5_parallel.data","alpha0.6_d5_parallel.data","alpha0.7_d5_parallel.data","alpha0.8_d5_parallel.data","alpha0.9_d5_parallel.data","alpha1.0_d5_parallel.data"]


plotn(6,datas,3,2,xlabel,ylabel,data_label,"d=5 toric, serial")
plotn(6,datap,3,2,xlabel,ylabel,data_label,"d=5 toric, parallel")

datas=["alpha0.5_d7_serial.data","alpha0.6_d7_serial.data","alpha0.7_d7_serial.data","alpha0.8_d7_serial.data","alpha0.9_d7_serial.data","alpha1.0_d7_serial.data"]
datap=["alpha0.5_d7_parallel.data","alpha0.6_d7_parallel.data","alpha0.7_d7_parallel.data","alpha0.8_d7_parallel.data","alpha0.9_d7_parallel.data","alpha1.0_d7_parallel.data"]


plotn(6,datas,3,2,xlabel,ylabel,data_label,"d=7 toric, serial")
plotn(6,datap,3,2,xlabel,ylabel,data_label,"d=7 toric, parallel")

datas=["alpha0.5_d9_serial.data","alpha0.6_d9_serial.data","alpha0.7_d9_serial.data","alpha0.8_d9_serial.data","alpha0.9_d9_serial.data","alpha1.0_d9_serial.data"]
datap=["alpha0.5_d9_parallel.data","alpha0.6_d9_parallel.data","alpha0.7_d9_parallel.data","alpha0.8_d9_parallel.data","alpha0.9_d9_parallel.data","alpha1.0_d9_parallel.data"]


plotn(6,datas,3,2,xlabel,ylabel,data_label,"d=9 toric, serial")
plotn(6,datap,3,2,xlabel,ylabel,data_label,"d=9 toric, parallel")

datas=["alpha0.5_d11_serial.data","alpha0.6_d11_serial.data","alpha0.7_d11_serial.data","alpha0.8_d11_serial.data","alpha0.9_d11_serial.data","alpha1.0_d11_serial.data"]
datap=["alpha0.5_d11_parallel.data","alpha0.6_d11_parallel.data","alpha0.7_d11_parallel.data","alpha0.8_d11_parallel.data","alpha0.9_d11_parallel.data","alpha1.0_d11_parallel.data"]


plotn(6,datas,3,2,xlabel,ylabel,data_label,"d=11 toric, serial")
plotn(6,datap,3,2,xlabel,ylabel,data_label,"d=11 toric, parallel")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3080/3784613510.py in <module>
#      15
#      16
# ---> 17 plotn(6,datas,3,2,xlabel,ylabel,data_label,"d=5 toric, serial")
#      18 plotn(6,datap,3,2,xlabel,ylabel,data_label,"d=5 toric, parallel")
#      19
#
# /tmp/ipykernel_3080/1565269455.py in plotn(n, data_file_list, x_index, y_index, xlabel, ylabel, data_label_list, title, lfit)
#      31
#      32     for i in range(n):
# ---> 33         data=pd.read_csv(data_file_list[i],sep='\s+',header=None)
#      34         x=data[x_index]
#      35         y=data[y_index]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = pd.read_csv('data_t.txt',sep='\s+',header=None)
x = data[0]
y = data[1]
plt.xlabel('n')
plt.ylabel('# of suc_dec')
plt.plot(x, y)
plt.savefig('pic1.png')

# %%
x = data[0]
y = data[2]
plt.xlabel('n')
plt.ylabel('average iterations')
plt.plot(x, y)

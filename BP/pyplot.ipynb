# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data4= pd.read_csv('p0.01_data.txt',sep='\s+',header=None)
x=data4[0]
y=data4[1]
plt.xlabel('n')
plt.ylabel('# of sec decoding')
plt.plot(x, y)

# %%
data5= pd.read_csv('n128_data.txt',sep='\s+',header=None)
x=data5[2]
y=data5[1]
plt.xlabel('p')
plt.ylabel('# of sec decoding')
plt.plot(x, y)

# %%
x=data4[0]
y=data4[3]
plt.xlabel('n')
plt.ylabel('average iteration')
plt.plot(x, y)

# %%
x=data5[2]
y=data5[3]
plt.xlabel('p')
plt.ylabel('average iteration')
plt.plot(x, y)
